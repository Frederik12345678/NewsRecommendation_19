# %%
import pickle

# Replace 'file_path.pkl' with the path to your .pkl file
PY_soft= "/Users/frederiknagel/Desktop/NewsRecommendation_19/Project_19/saved_loss/PY_soft.pkl"
PY_sig= "/Users/frederiknagel/Desktop/NewsRecommendation_19/Project_19/saved_loss/PY_sig.pkl"
PY_add_soft = "/Users/frederiknagel/Desktop/NewsRecommendation_19/Project_19/saved_loss/PY_add_soft.pkl"
PY_ffnn_soft = "/Users/frederiknagel/Desktop/NewsRecommendation_19/Project_19/saved_loss/PY_ffnn_soft.pkl"

# Open the file in read-binary mode and load its contents
with open(PY_soft, 'rb') as file:
    data_soft = pickle.load(file)

with open(PY_add_soft, 'rb') as file:
    data_add = pickle.load(file)

with open(PY_ffnn_soft, 'rb') as file:
    data_ffnn = pickle.load(file)

with open(PY_sig, 'rb') as file:
    data_sig = pickle.load(file)

loss_tensorflow = [1.5978, 1.5080, 1.4251, 1.3674, 1.3400, 1.3108, 1.2789, 1.2617, 1.2406, 1.2338, 1.2151, 1.2001, 1.1948,
                   1.1875, 1.1689, 1.1617, 1.1510, 1.1327, 1.1214, 1.1011, 1.0670, 1.0424, 1.0216, 0.9922, 0.9698, 0.9165,
                   0.8976, 0.8620, 0.8377, 0.8121 ]




"""
results = {
    "train_losses": train_loss,
    "val_losses": val_loss,
    "train_acc": train_acc,
    "val_acc": val_acc,
    "train_acc_1": train_acc_1,
    "val_acc_1": val_acc_1,
    "train_acc_0": train_acc_0,
    "val_acc_0": val_acc_0,
    "total_results": total_results,
    "total_results_string": total_results_string
}
"""
# Out:
# '\nresults = {\n    "train_losses": train_loss,\n    "val_losses": val_loss,\n    "train_acc": train_acc,\n    "val_acc": val_acc,\n    "train_acc_1": train_acc_1,\n    "val_acc_1": val_acc_1,\n    "train_acc_0": train_acc_0,\n    "val_acc_0": val_acc_0,\n    "total_results": total_results,\n    "total_results_string": total_results_string\n}\n'

# %% [markdown]
# ## Plot training loss

# %%
import matplotlib.pyplot as plt

epochs = range(30)

# Plot the losses
plt.figure(figsize=(10, 6))
plt.plot(epochs, data_soft['train_losses'], label="soft", color = "red")
plt.plot(epochs, data_add['train_losses'], label="Add", color = "green")
plt.plot(epochs, data_ffnn['train_losses'], label="ffnn", color = "blue")
plt.plot(epochs, data_sig['train_losses'], label="sig", color = "purple")
plt.plot(epochs, loss_tensorflow, label="Tensorflow", color = "black")

# Add titles and labels
plt.title("Training Loss for Multiple Models", fontsize=16)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Loss", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(epochs, data_sig['train_losses'], label="Train", color = "blue")
plt.plot(epochs, data_sig['val_losses'], label="Val", color = "red")

# Add titles and labels
plt.title("Training Loss for Multiple Models", fontsize=16)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Loss", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Overall Accuracy:

# %%
import matplotlib.pyplot as plt

epochs = range(30)

# Create the figure and subplots
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)  # 2 rows, 1 column, 1st plot
# Plot the losses
plt.plot(epochs, data_soft["train_acc"], label="Pytorch_soft", color = "red")
plt.plot(epochs, data_sig['train_acc'], label="Pytorch_sig", color = "purple")
plt.plot(epochs, data_add["train_acc"], label="Add", color = "green")
plt.plot(epochs, data_ffnn["train_acc"], label="ffnn", color = "blue")
plt.plot(epochs, data_soft["val_acc"], label="Pytorch_soft", color = "red",linestyle='dashed')
plt.plot(epochs, data_sig['val_acc'], label="Pytorch_sig", color = "purple",linestyle='dashed')
plt.plot(epochs, data_add["val_acc"], label="Add", color = "green",linestyle='dashed')
plt.plot(epochs, data_ffnn["val_acc"], label="ffnn", color = "blue",linestyle='dashed')
plt.title("Training Accuracy", fontsize=16)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)
#plt.legend(fontsize=12)
plt.grid(True)

# Add titles and labels
plt.subplot(1, 2, 2)  # 2 rows, 1 column, 2nd plot
plt.plot(epochs, data_soft["val_acc"], label="Pytorch_soft", color = "red")
plt.plot(epochs, data_sig['val_acc'], label="Pytorch_sig", color = "purple")
plt.plot(epochs, data_add["val_acc"], label="Add", color = "green")
plt.plot(epochs, data_ffnn["val_acc"], label="ffnn", color = "blue")
plt.title("Validation Accuracy", fontsize=16)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## O-label Accuracy

# %%
epochs = range(30)

# Create the figure and subplots
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)  # 2 rows, 1 column, 1st plot
# Plot the losses
plt.plot(epochs, data_soft["train_acc_0"], label="Pytorch", color = "red")
plt.plot(epochs, data_sig['train_acc_0'], label="Pytorch_sig", color = "purple")
plt.plot(epochs, data_add["train_acc_0"], label="Add", color = "green")
plt.plot(epochs, data_ffnn["train_acc_0"], label="ffnn", color = "blue")
plt.title("Training Accuracy", fontsize=16)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Add titles and labels
plt.subplot(1, 2, 2)  # 2 rows, 1 column, 2nd plot
plt.plot(epochs, data_soft["val_acc_0"], label="Pytorch", color = "red")
plt.plot(epochs, data_sig['val_acc_0'], label="Pytorch_sig", color = "purple")
plt.plot(epochs, data_add["val_acc_0"], label="Add", color = "green")
plt.plot(epochs, data_ffnn["val_acc_0"], label="ffnn", color = "blue")
plt.title("Validation Accuracy", fontsize=16)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## 1-label accuracy

# %%
# Create the figure and subplots
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)  # 2 rows, 1 column, 1st plot
# Plot the losses
plt.plot(epochs, data_soft["train_acc_1"], label="Pytorch", color = "red")
plt.plot(epochs, data_sig['train_acc_1'], label="Pytorch_sig", color = "purple")
plt.plot(epochs, data_add["train_acc_1"], label="Add", color = "green")
plt.plot(epochs, data_ffnn["train_acc_1"], label="ffnn", color = "blue")
plt.title("Training Accuracy", fontsize=16)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Add titles and labels
plt.subplot(1, 2, 2)  # 2 rows, 1 column, 2nd plot
plt.plot(epochs, data_soft["val_acc_1"], label="Pytorch", color = "red")
plt.plot(epochs, data_sig['val_acc_1'], label="Pytorch_sig", color = "purple")
plt.plot(epochs, data_add["val_acc_1"], label="Add", color = "green")
plt.plot(epochs, data_ffnn["val_acc_1"], label="ffnn", color = "blue")
plt.title("Validation Accuracy", fontsize=16)
plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Tabel of Results

# %%
import numpy as np

"""
<MetricEvaluator class>: 
 {
    "auc": 0.534879696432761,
    "mrr": 0.32782427323318186,
    "ndcg@5": 0.3658238538873502,
    "ndcg@10": 0.4491365109952377
}
Overall Accuracy: 79.18%
0-Label Accuracy: 85.00%
1-Label Accuracy: 15.89%
Training of ebnerd_small has finished
"""



string1 = data_soft["total_results"]
string2 = data_sig["total_results"]
string3 = data_add["total_results"]
string4 = data_ffnn["total_results"]

string = data_soft["total_results_string"]



print("         ",string[0], "    ",string[1],  "   ",string[2],  "   ",string[3], "   ", string[4],  "    ",string[5],  "   ",string[6])
print("________________________________________________________________________")
print("Softmax: ",np.round(string1[0],2), "   ",np.round(string1[1],2),  "   ",np.round(string1[2],2),  "   ",np.round(string1[3],2), "   ", string1[4],  "   ",string1[5],  "    ",string1[6])
print("Sigmoid: ",np.round(string2[0],2), "   ",np.round(string2[1],2),  "   ",np.round(string2[2],2),  "    ",np.round(string2[3],2), "   ", string2[4],  "   ",string2[5],  "    ",string2[6])
print("Add    : ",np.round(string3[0],2), "   ",np.round(string3[1],2),  "   ",np.round(string3[2],2),  "   ",np.round(string3[3],2), "   ", string3[4],  "    ",string3[5],  "   ",string3[6])
print("ffnn   : ",np.round(string4[0],2), "   ",np.round(string4[1],2),  "   ",np.round(string4[2],2),  "   ",np.round(string4[3],2), "    ", string4[4],  "    ",string4[5],  "   ",string4[6])
print("tf     : ","0.53", "   ","0.33",  "   ","0.36",  "   ","0.45", "   ", "79.2",  "    ","15.9",  "    ","85.0")
# Out:
#           AUC      Mrr     ndc5     ndc10     acc      acc_1     acc_0
# ________________________________________________________________________
# Softmax:  0.53     0.06     0.09     0.11     64.44     35.91      67.26
# Sigmoid:  0.53     0.06     0.1      0.11     90.28     0.82      99.08
# Add    :  0.54     0.06     0.09     0.11     71.8      26.02     76.29
# ffnn   :  0.54     0.06     0.09     0.1      9.25      100.0     0.31
# tf     :  0.53     0.33     0.36     0.45     79.2      15.9      85.0

# %%
epochs = range(30)
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 5))

# Make the figure background transparent
fig.patch.set_alpha(0.0)

# Loop through each subplot to make its background transparent
for ax in axes.flat:  # Flatten the 2D array of axes for easy iteration
    ax.set_facecolor((0, 0, 0, 0))  # Set the axes background to fully transparent (RGBA)

# Plot 1: Train/Validation Loss
axes[0, 0].plot(epochs, data_soft['train_losses'], label="Pytorch", color="red")
axes[0, 0].plot(epochs, data_add['train_losses'], label="Add", color="green")
axes[0, 0].plot(epochs, data_ffnn['train_losses'], label="ffnn", color="blue")
axes[0, 0].plot(epochs, data_sig['train_losses'], label="sig", color = "purple")
axes[0, 0].plot(epochs, loss_tensorflow, label="Tensorflow", color="black")

axes[0, 0].set_title('Training Loss')
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].grid(True)

# Plot 2: Train/Validation Accuracy
axes[0, 1].plot(epochs, data_soft["val_acc"], color="red")
axes[0, 1].plot(epochs, data_sig['val_acc'], label="Pytorch_sig", color="purple")
axes[0, 1].plot(epochs, data_add["val_acc"], color="green")
axes[0, 1].plot(epochs, data_ffnn["val_acc"], color="blue")
axes[0, 1].set_title('Total Validation Accuracy')
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].grid(True)

# Plot 3: Train/Validation Accuracy for label 0
axes[1, 0].plot(epochs, data_soft["val_acc_0"], color="red")
axes[1, 0].plot(epochs, data_sig['val_acc_0'], color="purple")
axes[1, 0].plot(epochs, data_add["val_acc_0"], color="green")
axes[1, 0].plot(epochs, data_ffnn["val_acc_0"], color="blue")
axes[1, 0].set_title('0-label Validation Accuracy')
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Accuracy (label=0)')
axes[1, 0].grid(True)

# Plot 4: Train/Validation Accuracy for label 1
axes[1, 1].plot(epochs, data_soft["val_acc_1"], color="red")
axes[1, 1].plot(epochs, data_sig['val_acc_1'], color="purple")
axes[1, 1].plot(epochs, data_add["val_acc_1"], color="green")
axes[1, 1].plot(epochs, data_ffnn["val_acc_1"], color="blue")
axes[1, 1].set_title('1-label Validation Accuracy')
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Accuracy (label=1)')
axes[1, 1].grid(True)

# Adjust layout to make room for the legend
fig.subplots_adjust(bottom=0.4)  # Add space below the plots for the legend

# Add a single legend below the plots
fig.legend(loc='lower center', ncol=2, fontsize=8, bbox_to_anchor=(0.52, -0.085))  # Adjust bbox

plt.tight_layout()
# Display the plot
plt.show()
